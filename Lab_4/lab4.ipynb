# %% [markdown]
# Задание 1

# %%
import math
import datetime
dt=datetime.datetime.today()
print(math.sqrt(144))
print(dt)
# Out:
# 12.0
# 2024-10-13 16:29:51.113207

# %% [markdown]
# Задание 2

# %%
from rep import*
print(rep.f(12,42))
print(rep.func('123'))
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-14-9679c85cf15c> in <cell line: 1>()
# ----> 1 from rep import*
#       2 print(rep.f(12,42))
#       3 print(rep.func('123'))
#
# ModuleNotFoundError: No module named 'rep'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %% [markdown]
# Задание 3

# %%
import my_package.module1
import my_package.module2_1
se=[1,2,3,4,5,6]
my_package.module1.repos(se)
my_package.module2_1.razvorot('123')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-15-d1d1482a284b> in <cell line: 1>()
# ----> 1 import my_package.module1
#       2 import my_package.module2_1
#       3 se=[1,2,3,4,5,6]
#       4 my_package.module1.repos(se)
#       5 my_package.module2_1.razvorot('123')
#
# ModuleNotFoundError: No module named 'my_package.module1'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------
